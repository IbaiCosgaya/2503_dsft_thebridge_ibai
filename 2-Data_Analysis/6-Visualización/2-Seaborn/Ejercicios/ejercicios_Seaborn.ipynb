# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
pokemon = pd.read_csv('data/Pokemon.csv')
pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data
# y = a*x + b
# 50 = a *40 + b

# %%
# numeric_data = pokemon.select_dtypes(include='number')

# sns.pairplot(numeric_data, kind='reg', plot_kws={'line_kws':{'color':'red'}})

# plt.suptitle("Regresión Lineal para todas las columnas numéricas", y=1.02)
# plt.show()

# %%
sns.lmplot(
    x="Attack",     
    y="Defense",     
    data=pokemon,     
    aspect=1.5,      
    line_kws={"color": "red"},  # Línea de regresión en rojo
    scatter_kws={"alpha": 0.6, "color": "blue"}  # Puntos en azul con transparencia
)

plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Relación entre Ataque y Defensa en Pokémon")
plt.show()

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

# %%
sns.lmplot(
    x="Attack",     
    y="Defense",     
    data=pokemon,     
    aspect=1.5,      
    line_kws={"color": "red"},  # Línea de regresión en rojo
    scatter_kws={"alpha": 0.6, "color": "blue"},   # Puntos en azul con transparencia
    fit_reg= False
)

plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Relación entre Ataque y Defensa en Pokémon")
plt.show()

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

sns.lmplot(
    x="Attack",      
    y="Defense",     
    data=pokemon,       
    hue="Stage",     # Codificación de color usando 'Stage'
    aspect=1.5,
    scatter_kws={"alpha": 0.7}  
)

plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Relación entre Ataque y Defensa con Hue por 'Stage'")
plt.show()

# %%
# 8. Limita el eje x entre 20 y 100

sns.lmplot(
    x="Attack",      
    y="Defense",     
    data=pokemon,       
    hue="Stage",     # Codificación de color usando 'Stage'
    aspect=1.5,
    scatter_kws={"alpha": 0.7}  
)

plt.xlabel("Attack")
plt.xlim(20,100)
plt.ylabel("Defense")
plt.title("Relación entre Ataque y Defensa con Hue por 'Stage'")
plt.show()

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

sns.boxplot(data=pokemon.select_dtypes(include='number'), palette="Set2")

plt.title("Diagrama de Cajas para todas las columnas numéricas")
plt.show()

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

borrar = pokemon.drop(columns=['Total', 'Stage', 'Legendary'])

sns.boxplot(data=borrar.select_dtypes(include='number'), palette="Set1")

plt.title("Diagrama de Cajas para todas las columnas numéricas")
plt.show()

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

tipo_1 = pokemon["Type 1"].unique()
len(tipo_1)
# Out:
# 15

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

mask = pokemon[(pokemon["Type 1"] == "Grass") | (pokemon["Type 1"] == "Fire") | (pokemon["Type 1"] == "Water")]
mask
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass    Poison    318   45      49       49       65
# 1      2     Ivysaur  Grass    Poison    405   60      62       63       80
# 2      3    Venusaur  Grass    Poison    525   80      82       83      100
# 3      4  Charmander   Fire       NaN    309   39      52       43       60
# 4      5  Charmeleon   Fire       NaN    405   58      64       58       80
# 5      6   Charizard   Fire    Flying    534   78      84       78      109
# 6      7    Squirtle  Water       NaN    314   44      48       65       50
# 7      8   Wartortle  Water       NaN    405   59      63       80       65
# 8      9   Blastoise  Water       NaN    530   79      83      100       85
# 36    37      Vulpix   Fire       NaN    299   38      41       40       50
# 37    38   Ninetales   Fire       NaN    505   73      76       75       81
# 42    43      Oddish  Grass    Poison    320   45      50       55       75
# 43    44       Gloom  Grass    Poison    395   60      65       70       85
# 44    45   Vileplume  Grass    Poison    490   75      80       85      110
# 53    54     Psyduck  Water       NaN    320   50      52       48       65
# 54    55     Golduck  Water       NaN    500   80      82       78       95
# 57    58   Growlithe   Fire       NaN    350   55      70       45       70
# 58    59    Arcanine   Fire       NaN    555   90     110       80      100
# 59    60     Poliwag  Water       NaN    300   40      50       40       40
# 60    61   Poliwhirl  Water       NaN    385   65      65       65       50
# 61    62   Poliwrath  Water  Fighting    510   90      95       95       70
# 68    69  Bellsprout  Grass    Poison    300   50      75       35       70
# 69    70  Weepinbell  Grass    Poison    390   65      90       50       85
# 70    71  Victreebel  Grass    Poison    490   80     105       65      100
# 71    72   Tentacool  Water    Poison    335   40      40       35       50
# 72    73  Tentacruel  Water    Poison    515   80      70       65       80
# 76    77      Ponyta   Fire       NaN    410   50      85       55       65
# 77    78    Rapidash   Fire       NaN    500   65     100       70       80
# 78    79    Slowpoke  Water   Psychic    315   90      65       65       40
# 79    80     Slowbro  Water   Psychic    490   95      75      110      100
# 85    86        Seel  Water       NaN    325   65      45       55       45
# 86    87     Dewgong  Water       Ice    475   90      70       80       70
# 89    90    Shellder  Water       NaN    305   30      65      100       45
# 90    91    Cloyster  Water       Ice    525   50      95      180       85
# 97    98      Krabby  Water       NaN    325   30     105       90       25
# 98    99     Kingler  Water       NaN    475   55     130      115       50
# 101  102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 102  103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 113  114     Tangela  Grass       NaN    435   65      55      115      100
# 115  116      Horsea  Water       NaN    295   30      40       70       70
# 116  117      Seadra  Water       NaN    440   55      65       95       95
# 117  118     Goldeen  Water       NaN    320   45      67       60       35
# 118  119     Seaking  Water       NaN    450   80      92       65       65
# 119  120      Staryu  Water       NaN    340   30      45       55       70
# 120  121     Starmie  Water   Psychic    520   60      75       85      100
# 125  126      Magmar   Fire       NaN    495   65      95       57      100
# 128  129    Magikarp  Water       NaN    200   20      10       55       15
# 129  130    Gyarados  Water    Flying    540   95     125       79       60
# 130  131      Lapras  Water       Ice    535  130      85       80       85
# 133  134    Vaporeon  Water       NaN    525  130      65       60      110
# 135  136     Flareon   Fire       NaN    525   65     130       60       95
# 145  146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# 5         85    100      3      False
# 6         64     43      1      False
# 7         80     58      2      False
# 8        105     78      3      False
# 36        65     65      1      False
# 37       100    100      2      False
# 42        65     30      1      False
# 43        75     40      2      False
# 44        90     50      3      False
# 53        50     55      1      False
# 54        80     85      2      False
# 57        50     60      1      False
# 58        80     95      2      False
# 59        40     90      1      False
# 60        50     90      2      False
# 61        90     70      3      False
# 68        30     40      1      False
# 69        45     55      2      False
# 70        70     70      3      False
# 71       100     70      1      False
# 72       120    100      2      False
# 76        65     90      1      False
# 77        80    105      2      False
# 78        40     15      1      False
# 79        80     30      2      False
# 85        70     45      1      False
# 86        95     70      2      False
# 89        25     40      1      False
# 90        45     70      2      False
# 97        25     50      1      False
# 98        50     75      2      False
# 101       45     40      1      False
# 102       65     55      2      False
# 113       40     60      1      False
# 115       25     60      1      False
# 116       45     85      2      False
# 117       50     63      1      False
# 118       80     68      2      False
# 119       55     85      1      False
# 120       85    115      2      False
# 125       85     93      1      False
# 128       20     80      1      False
# 129      100     81      2      False
# 130       95     60      1      False
# 133       95     65      2      False
# 135      110     65      2      False
# 145       85     90      1       True

# %%
# 13. Usa un estilo 'whitegrid'
sns.set(style="whitegrid")

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

sns.violinplot(x='Type 1', y='Attack', data=mask, palette="Set2")

plt.title('Distribución de Attack por Tipo (Agua, Fuego, Hierba)')
plt.xlabel('Tipo')
plt.ylabel('Attack')

plt.show()
# Out:
# C:\Users\ibai\AppData\Local\Temp\ipykernel_1176\2758536650.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Type 1', y='Attack', data=mask, palette="Set2")

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

colores = ['#78C850', '#F08030', '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

sns.violinplot(x='Type 1', y='Attack', data=mask, palette=colores)

plt.title('Distribución de Attack por Tipo (Agua, Fuego, Hierba)')
plt.xlabel('Tipo')
plt.ylabel('Attack')

plt.show()
# Out:
# C:\Users\ibai\AppData\Local\Temp\ipykernel_1176\14537092.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Type 1', y='Attack', data=mask, palette=colores)

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

sns.swarmplot(x='Type 1', y='Attack', data=mask, palette=colores)

plt.title('Distribución de Attack por Tipo (Agua, Fuego, Hierba) con Swarmplot')
plt.xlabel('Tipo')
plt.ylabel('Attack')

plt.show()
# Out:
# C:\Users\ibai\AppData\Local\Temp\ipykernel_1176\4238169278.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Type 1', y='Attack', data=mask, palette=colores)

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

sns.violinplot(x='Type 1', y='Attack', data=mask, palette=colores, inner=None)
sns.swarmplot(x='Type 1', y='Attack', data=mask, color="black")

plt.title('Distribución de Attack por Tipo (Agua, Fuego, Hierba) con Swarmplot')
plt.xlabel('Tipo')
plt.ylabel('Attack')

plt.show()
# Out:
# C:\Users\ibai\AppData\Local\Temp\ipykernel_1176\991099322.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Type 1', y='Attack', data=mask, palette=colores, inner=None)

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

mask.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

mask_melted = mask.melt(
    id_vars=['Name', 'Type 1'], 
    value_vars=['Attack', 'Defense', 'Speed', "HP", "Sp. Atk", "Sp. Def"], 
    var_name='New Column', 
    value_name='Value'
    )

mask_melted
# Out:
#            Name Type 1 New Column  Value
# 0     Bulbasaur  Grass     Attack     49
# 1       Ivysaur  Grass     Attack     62
# 2      Venusaur  Grass     Attack     82
# 3    Charmander   Fire     Attack     52
# 4    Charmeleon   Fire     Attack     64
# ..          ...    ...        ...    ...
# 307    Gyarados  Water    Sp. Def    100
# 308      Lapras  Water    Sp. Def     95
# 309    Vaporeon  Water    Sp. Def     95
# 310     Flareon   Fire    Sp. Def    110
# 311     Moltres   Fire    Sp. Def     85
#
# [312 rows x 4 columns]

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

sns.swarmplot(x='Value', y='New Column', data=mask_melted, hue="Type 1")

plt.title('Distribución de valores por columna (Attack, Defense, Speed)')
plt.xlabel('Valor')
plt.ylabel('Columna Original')

plt.show()

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

plt.figure(figsize=(10,6))
sns.swarmplot(y='Value', x='New Column', data=mask_melted, palette=colores, dodge=True, hue="Type 1")

plt.title('Distribución de valores por columna (Attack, Defense, Speed)')
plt.ylim(0,200)
plt.xlabel('Valor')
plt.ylabel('Columna Original')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, title='Leyenda')

plt.show()

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

correlaciones = pokemon.select_dtypes(include=['number']).corr()

# Mostrar la matriz de correlación
correlaciones
# Out:
#                 #     Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #        1.000000  0.386403  0.204389  0.260973  0.325882  0.255471  0.254515
# Total    0.386403  1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP       0.204389  0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack   0.260973  0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense  0.325882  0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk  0.255471  0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def  0.254515  0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed    0.132233  0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage   -0.274544  0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
#
#             Speed     Stage
# #        0.132233 -0.274544
# Total    0.506950  0.504224
# HP      -0.040939  0.249207
# Attack   0.194701  0.361321
# Defense -0.053252  0.270861
# Sp. Atk  0.411516  0.391712
# Sp. Def  0.392656  0.358308
# Speed    1.000000  0.240042
# Stage    0.240042  1.000000

# %%
# ¿la correlación entre qué valores se encuentra?
# -1 y 1

# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# que siempre será 1

# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación

# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)
# Usa un mapa de calor, destacando solo valores altos o bajos, para enfocarte en correlaciones significativas.

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

sns.histplot(pokemon['Defense'], kde=True, color="blue", bins=20)

plt.xlabel('Nivel de Defensa')
plt.ylabel('Frecuencia / Densidad')
plt.title('Histograma y Densidad de Probabilidad del Nivel de Defensa')

plt.show()

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

sns.countplot(data=pokemon, x='Type 1', palette="viridis")

plt.xticks(rotation=45)
plt.xlabel('Tipo (Type 1)')
plt.ylabel('Cantidad')
plt.title('Distribución de Pokémon por Tipo')

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\ibai\AppData\Local\Temp\ipykernel_1176\2250397584.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pokemon, x='Type 1', palette="viridis")

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

g = sns.catplot(
    data=pokemon,
    x='Type 1',
    y='Defense',
    hue='Type 2',
    col='Legendary',
    kind='strip',  
    palette='viridis',
    height=6,
    aspect=1.5
)

g.set_xticklabels(rotation=45) 
g.set_axis_labels('Tipo Principal (Type 1)', 'Defensa')  
g.set_titles('Legendarios: {col_name}')

plt.show()

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

plt.figure(figsize=(8, 6)) 
sns.kdeplot(
    data=pokemon,
    x='Attack',
    y='Defense',
    cmap='inferno',
    fill=True,  # Rellenar las curvas de nivel
    levels=50,  #(bins 2D)
)

plt.title('Curvas de Nivel: Defensa vs Ataque')
plt.xlabel('Ataque')
plt.ylabel('Defensa')

plt.show()

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

sns.jointplot(
    x='Attack', 
    y='Defense', 
    data=pokemon, 
    kind='kde',  # Tipo de gráfico, puede ser 'kde', 'scatter', 'hex', 'reg', etc.
    cmap='magma', 
    fill=True,  # Rellenar las curvas de nivel
    levels=50,
)

# Título y mostrar el gráfico
plt.suptitle('Distribución Conjunta de Defensa vs Ataque', y=1.02)
plt.show()
